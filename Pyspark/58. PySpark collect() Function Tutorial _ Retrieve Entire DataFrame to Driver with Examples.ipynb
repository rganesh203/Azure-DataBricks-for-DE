# %% [markdown]
# # 🧠 PySpark collect() Function:
# 🔹 Purpose:
#
# The collect() function in PySpark is used to retrieve all rows of a DataFrame (or RDD) from the executors (worker nodes) back to the driver program as a list of Row objects.
#
# It’s typically used for small datasets or for debugging, not for large-scale distributed data because it brings everything into driver memory.

# %%
#Step 1: Create a Sample DataFrame
data = [
    (1, "Alice", 3500),
    (2, "Bob", 4000),
    (3, "Charlie", 4500),
    (4, "David", 5000)
]

columns = ["emp_id", "name", "salary"]

df = spark.createDataFrame(data, columns)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>3500</td></tr><tr><td>2</td><td>Bob</td><td>4000</td></tr><tr><td>3</td><td>Charlie</td><td>4500</td></tr><tr><td>4</td><td>David</td><td>5000</td></tr></tbody></table></div>

# %%
data_collect = df.collect()

# Print the entire data collected to driver
for i in data_collect:
    print(i)
# Out:
# Row(emp_id=1, name='Alice', salary=3500)
# Row(emp_id=2, name='Bob', salary=4000)
# Row(emp_id=3, name='Charlie', salary=4500)
# Row(emp_id=4, name='David', salary=5000)

# %%
# Access individual elements
for row in data_collect:
    print(row.name, "earns", row.salary)
# Out:
# Alice earns 3500
# Bob earns 4000
# Charlie earns 4500
# David earns 5000

# %% [markdown]
# ### ⚠️ Important Notes
#
# collect() brings all data to the driver memory, so avoid using it for large datasets.
#
# If your DataFrame is large, use alternatives like:
#
# .take(n) → retrieves first n rows safely
#
# .limit(n).toPandas() → converts small subset to Pandas DataFrame
#
# .show() → prints preview without moving all data

# %% [markdown]
# ### ✅ Summary
# | Function    | Purpose            | Returns      | Safe for Large Data |
# | ----------- | ------------------ | ------------ | ------------------- |
# | `collect()` | Fetches all rows   | List of Rows | ❌ No                |
# | `take(n)`   | Fetches top n rows | List of Rows | ✅ Yes               |
# | `show(n)`   | Prints top n rows  | None         | ✅ Yes               |
